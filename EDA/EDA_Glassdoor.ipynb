# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
#
# ### Análisis exploratorio de datos sobre dataset de Glassdoor
#
# #### **Notebook de Noe**  👻
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ### Archivo: country_names_2_digit_codes.csv
#
# Este archivo contiene codigos de paises
#
#
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
# Codigo de paises
df1 = pd.read_csv('../data/glassdoor/country_names_2_digit_codes.csv')
df1.head()
# Out:
#              Name Code
# 0     Afghanistan   AF
# 1  Ã…land Islands   AX
# 2         Albania   AL
# 3         Algeria   DZ
# 4  American Samoa   AS

# %%
df1.shape
# Out:
# (249, 2)

# %%
df1.isna().sum()
# Out:
# Name    0
# Code    1
# dtype: int64

# %%
# Namibia no tiene codigo
df1.loc[df1['Code'].isna()]
# Out:
#         Name Code
# 153  Namibia  NaN

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ### Archivo: currency_exchange.csv
#
# Archivo que contiene datos del ratio de cambio de la moneda local a (creo) dolares
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
# No tengo ni idea de que es esto
df2 = pd.read_csv('../data/glassdoor/currency_exchange.csv')
df2.head()
# Out:
#   Code                     Country                       Currency  Number
# 0  AED  United Arab Emirates (The)                     UAE Dirham   784.0  \
# 1  AFN                 Afghanistan                        Afghani   971.0
# 2  ALL                     Albania                            Lek     8.0
# 3  AMD                     Armenia                  Armenian Dram    51.0
# 4  ANG                     Curaçao  Netherlands Antillean Guilder   532.0
#
#    ExchangeRate
# 0      3.672779
# 1     78.250197
# 2    111.702860
# 3    477.169811
# 4      1.734311

# %%
df2.shape
# Out:
# (268, 5)

# %%
df2.isna().sum()
# Out:
# Code             3
# Country          0
# Currency         0
# Number           3
# ExchangeRate    15
# dtype: int64

# %%
# Que datos faltan??
df2.loc[df2['Code'].isna()]
# Out:
#     Code                                       Country               Currency
# 265  NaN                                    Antarctica  No universal currency  \
# 266  NaN                           Palestine, State Of  No universal currency
# 267  NaN  South Georgia And The South Sandwich Islands  No universal currency
#
#      Number  ExchangeRate
# 265     NaN           NaN
# 266     NaN           NaN
# 267     NaN           NaN

# %%
df2.loc[df2['Number'].isna()]
# Out:
#     Code                                       Country               Currency
# 265  NaN                                    Antarctica  No universal currency  \
# 266  NaN                           Palestine, State Of  No universal currency
# 267  NaN  South Georgia And The South Sandwich Islands  No universal currency
#
#      Number  ExchangeRate
# 265     NaN           NaN
# 266     NaN           NaN
# 267     NaN           NaN

# %%
df2.loc[df2['ExchangeRate'].isna()]
# Out:
#     Code                                            Country
# 27   BOV                   Bolivia (Plurinational State Of)  \
# 36   CHE                                        Switzerland
# 39   CHW                                        Switzerland
# 44   COU                                           Colombia
# 145  MRU                                         Mauritania
# 150  MXV                                             Mexico
# 188  SSP                                        South Sudan
# 189  STN                              Sao Tome And Principe
# 223  USN                     United States Of America (The)
# 224  UYI                                            Uruguay
# 257  XSU  Sistema Unitario De Compensacion Regional De P...
# 258  XUA  Member Countries Of The African Development Ba...
# 265  NaN                                         Antarctica
# 266  NaN                                Palestine, State Of
# 267  NaN       South Georgia And The South Sandwich Islands
#
# ...

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ### Archivo: glassdoor_benefits_highlights.csv
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
df5 = pd.read_csv('../data/glassdoor/glassdoor_benefits_highlights.csv')
df5.head()
# Out:
#       id            benefits.highlights.val.highlightPhrase
# 0  44001             good flexibility for working from home  \
# 1  44001  I’ve not really had any time off for the last ...
# 2  44001  Very flexible if you don't work overtime and y...
# 3  44002                                                NaN
# 4  44003                                                NaN
#
#   benefits.highlights.val.icon benefits.highlights.val.name  index
# 0                          wfh               Work From Home    0.0  \
# 1                     sickDays                     Sick Pay    1.0
# 2                flexWorkSched             Flexible Working    2.0
# 3                          NaN                          NaN    NaN
# 4                          NaN                          NaN    NaN
#
#    benefits.highlights.val.commentCount
# 0                                  17.0
# 1                                  14.0
# 2                                   7.0
# ...

# %%
df5.shape
# Out:
# (212155, 6)

# %%
df5.isna().sum()
# Out:
# id                                              0
# benefits.highlights.val.highlightPhrase    132255
# benefits.highlights.val.icon               132255
# benefits.highlights.val.name               132255
# index                                      132255
# benefits.highlights.val.commentCount       132255
# dtype: int64

# %%
df5.dropna(inplace=True)
df5.head()
# Out:
#        id            benefits.highlights.val.highlightPhrase
# 0   44001             good flexibility for working from home  \
# 1   44001  I’ve not really had any time off for the last ...
# 2   44001  Very flexible if you don't work overtime and y...
# 9   44008               Nothing special to write about here
# 13  44012          They offer sick pay when you are off sick
#
#    benefits.highlights.val.icon benefits.highlights.val.name  index
# 0                           wfh               Work From Home    0.0  \
# 1                      sickDays                     Sick Pay    1.0
# 2                 flexWorkSched             Flexible Working    2.0
# 9                      sickDays                     Sick Pay    0.0
# 13                     sickDays                     Sick Pay    0.0
#
#     benefits.highlights.val.commentCount
# 0                                   17.0
# 1                                   14.0
# 2                                    7.0
# ...

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ### Archivo: glassdoor.csv
#
# Este archivo contiene 165290 filas y 163 columnas.
#
# > Tiene muchisima missing data. Hay que analizar y limpiar.
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
# Aca estan los datos jugosos
df3 = pd.read_csv('../data/glassdoor/glassdoor.csv')
df3.head()
# Out:
#    benefits.benefitRatingDecimal  benefits.comments  benefits.highlights
# 0                            0.0             2801.0               2801.0  \
# 1                            4.0             2802.0               2802.0
# 2                            0.0             2803.0               2803.0
# 3                            0.0             2804.0               2804.0
# 4                            0.0             2805.0               2805.0
#
#    benefits.numRatings benefits.employerSummary  breadCrumbs
# 0                    0                      NaN         2801  \
# 1                    3                      NaN         2802
# 2                    0                      NaN         2803
# 3                    0                      NaN         2804
# 4                    0                      NaN         2805
#
#    gaTrackerData.category  gaTrackerData.empId  gaTrackerData.empName
# 0                      -1              2183810            Modus Group  \
# ...

# %%
df3.shape
# Out:
# (165290, 163)

# %%
# Muucho missing data
df3.isna().sum()
# Out:
# benefits.benefitRatingDecimal                                        0
# benefits.comments                                                    1
# benefits.highlights                                                  1
# benefits.numRatings                                                  0
# benefits.employerSummary                                        159541
# breadCrumbs                                                          0
# gaTrackerData.category                                               0
# gaTrackerData.empId                                                  0
# gaTrackerData.empName                                            18209
# gaTrackerData.empSize                                            18209
# gaTrackerData.expired                                                0
# gaTrackerData.industry                                           47405
# gaTrackerData.industryId                                             0
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Columns: 163 entries, benefits.benefitRatingDecimal to wwfu
# dtypes: bool(11), float64(35), int64(23), object(94)
# memory usage: 193.4+ MB

# %% [markdown]
# ---
# #### Lista de columnas
#
# ---

# %%
glassdoor_cols = df3.columns.tolist()
glassdoor_cols
# Out:
# ['benefits.benefitRatingDecimal',
#  'benefits.comments',
#  'benefits.highlights',
#  'benefits.numRatings',
#  'benefits.employerSummary',
#  'breadCrumbs',
#  'gaTrackerData.category',
#  'gaTrackerData.empId',
#  'gaTrackerData.empName',
#  'gaTrackerData.empSize',
#  'gaTrackerData.expired',
#  'gaTrackerData.industry',
#  'gaTrackerData.industryId',
#  'gaTrackerData.jobId.long',
#  'gaTrackerData.jobId.int',
#  'gaTrackerData.jobTitle',
#  'gaTrackerData.location',
#  'gaTrackerData.locationId',
#  'gaTrackerData.locationType',
#  'gaTrackerData.pageRequestGuid.guid',
#  'gaTrackerData.pageRequestGuid.guidValid',
#  'gaTrackerData.pageRequestGuid.part1',
#  'gaTrackerData.pageRequestGuid.part2',
#  'gaTrackerData.sector',
#  'gaTrackerData.sectorId',
#  'gaTrackerData.profileConversionTrackingParams.trackingCAT',
#  'gaTrackerData.profileConversionTrackingParams.trackingSRC',
#  'gaTrackerData.profileConversionTrackingParams.trackingXSP',
# ...

# %% [markdown]
# ---![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ### Los datos parecen estar separados en categorias
# - benefits
# - breadCrumbs
# - gaTrackerData
# - header
# - job
# - map
# - overview
# - photos
# - rating
# - reviews
# - salary
# - wwfu
#
#
# > Vamos a aplicar una estrategia de divide and conquer.
#
# Vamos a generar un dataframe para cada categoria para poder analizarlo de manera mas comoda
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
category = [ 'benefits', 'breadCrumbs','gaTrackerData', 'header', 'job', 'map', 'overview', 'photos', 'rating', 'reviews', 'salary', 'wwfu']

# Voy a crear un diccionario con dataframes para cada categoria
cat_dict_dfs = {}

for c in category:
    cat_dict_dfs['df_'+c] = df3.filter(regex='^'+c)

# %%
# Nombres de los dataframes
df_names= list(cat_dict_dfs.keys())

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Analisis exploratorio inicial sobre las categorias
#
# Miramos cada una de las 12 categorias para identificar donde esta la info relevante
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# #### Benefits
#
# Columnas importantes:
# No
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
# Benefits
i = 0
benefits = cat_dict_dfs[df_names[i]]
print('---------------------------------------------------------------------------------')
print(f"Categoria: {df_names[i]}")
print(benefits.head())
print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Categoria: df_benefits
#    benefits.benefitRatingDecimal  benefits.comments  benefits.highlights
# 0                            0.0             2801.0               2801.0  \
# 1                            4.0             2802.0               2802.0
# 2                            0.0             2803.0               2803.0
# 3                            0.0             2804.0               2804.0
# 4                            0.0             2805.0               2805.0
#
#    benefits.numRatings benefits.employerSummary
# 0                    0                      NaN
# 1                    3                      NaN
# 2                    0                      NaN
# 3                    0                      NaN
# 4                    0                      NaN
# ---------------------------------------------------------------------------------

# %%
benefits.isna().sum()
# Out:
# benefits.benefitRatingDecimal         0
# benefits.comments                     1
# benefits.highlights                   1
# benefits.numRatings                   0
# benefits.employerSummary         159541
# dtype: int64

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# #### breadCrumbs
#
# ¿Migas de pan???
# No se a que se refiere esta columna --> investigar
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
# breadCrumbs --> ¡¿ Migas de pan?!
i = 1
breadCrumbs = cat_dict_dfs[df_names[i]]
print('---------------------------------------------------------------------------------')
print(f"Categoria: {df_names[i]}")
print(breadCrumbs.head())
print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Categoria: df_breadCrumbs
#    breadCrumbs
# 0         2801
# 1         2802
# 2         2803
# 3         2804
# 4         2805
# ---------------------------------------------------------------------------------

# %%
breadCrumbs.isna().sum()
# Out:
# breadCrumbs    0
# dtype: int64

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# #### gaTrackerData
# Informacion sobre las empresas, cantidad de empleados,sector, etc
#
# **Columnas interesantes para revisar:**
# * gaTrackerData.empName
# * gaTrackerData.empSize
# * gaTrackerData.industry
# * gaTrackerData.jobTitle
# * gaTrackerData.location
# * gaTrackerData.sector
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
i = 2

gaTrackerData = cat_dict_dfs[df_names[i]]
print('---------------------------------------------------------------------------------')
print(f"Categoria: {df_names[i]}")
print(gaTrackerData.head())
print('---------------------------------------------------------------------------------')


gaTrackerData_sel_col = ['gaTrackerData.empName', 'gaTrackerData.empSize',\
                        'gaTrackerData.industry','gaTrackerData.jobTitle',\
                        'gaTrackerData.location', 'gaTrackerData.sector']
# Out:
# ---------------------------------------------------------------------------------
# Categoria: df_gaTrackerData
#    gaTrackerData.category  gaTrackerData.empId  gaTrackerData.empName
# 0                      -1              2183810            Modus Group  \
# 1                      -1                10416   Boehringer Ingelheim
# 2                      -1              1043373        Immobiliare.it
# 3                      -1              2226886                  Codup
# 4                      -1               851555  Markelytics Solutions
#
#   gaTrackerData.empSize  gaTrackerData.expired
# 0              501-1000                  False  \
# 1              10000--1                  False
# 2               201-500                  False
# 3                  1-50                  False
# 4               201-500                  False
#
#                   gaTrackerData.industry  gaTrackerData.industryId
# 0  Investment Banking & Asset Management                    200053  \
# ...

# %%
gaTrackerData_sel = gaTrackerData[gaTrackerData_sel_col]
gaTrackerData_sel.head()
# Out:
#    gaTrackerData.empName gaTrackerData.empSize
# 0            Modus Group              501-1000  \
# 1   Boehringer Ingelheim              10000--1
# 2        Immobiliare.it                201-500
# 3                  Codup                  1-50
# 4  Markelytics Solutions               201-500
#
#                   gaTrackerData.industry
# 0  Investment Banking & Asset Management  \
# 1              Biotech & Pharmaceuticals
# 2                                    NaN
# 3                                    NaN
# 4                             Consulting
#
#                               gaTrackerData.jobTitle gaTrackerData.location
# 0                 Biogas Project Development Manager                 Warsaw  \
# 1  Quality Manager - Boehringer Ingelheim Healthc...                    NaN
# 2     Senior Software Engineer (PHP, Elixir, Python)                 Milano
# 3                                Senior SQA Engineer                Karachi
# ...

# %%
gaTrackerData_sel.isna().sum()
# Out:
# gaTrackerData.empName     18209
# gaTrackerData.empSize     18209
# gaTrackerData.industry    47405
# gaTrackerData.jobTitle        0
# gaTrackerData.location    70283
# gaTrackerData.sector      47373
# dtype: int64

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# #### Header
#
# **Columnas importantes**
# - header.employerName
# - header.jobTitle
# - header.payHigh
# - header.payLow
# - header.payMed
# - header.payPeriod
# - header.salaryHigh
# - header.salaryLow
# - header.salarySource
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
i = 3
header = cat_dict_dfs[df_names[i]]
print('---------------------------------------------------------------------------------')
print(f"Categoria: {df_names[i]}")
print(header.head())
print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Categoria: df_header
#    header.adOrderId header.advertiserType  header.applicationId
# 0             14295               GENERAL                     0  \
# 1             43297               GENERAL                     0
# 2            437149               GENERAL                     0
# 3            389273             JOB_BOARD                     0
# 4            437149               GENERAL                     0
#
#    header.applyButtonDisabled
# 0                       False  \
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
#                                      header.applyUrl  header.blur
# 0  /partner/jobListing.htm?pos=101&ao=14295&tgt=A...         True  \
# 1  /partner/jobListing.htm?pos=101&ao=43297&s=58&...         True
# 2  /partner/jobListing.htm?pos=101&ao=437149&s=58...         True
# ...

# %%
header_sel_col = ["header.employerName", "header.jobTitle", \
"header.payHigh", "header.payLow", "header.payMed" , "header.payPeriod", \
"header.salaryHigh", "header.salaryLow" , "header.salarySource"]

header_sel = header[header_sel_col]
header_sel.head()
# Out:
#            header.employerName
# 0                  Modus Group  \
# 1         Boehringer Ingelheim
# 2               Immobiliare.it
# 3                        Codup
# 4  MARKELYTICS SOLUTIONS INDIA
#
#                                      header.jobTitle  header.payHigh
# 0                 Biogas Project Development Manager             NaN  \
# 1  Quality Manager - Boehringer Ingelheim Healthc...             NaN
# 2     Senior Software Engineer (PHP, Elixir, Python)             NaN
# 3                                Senior SQA Engineer             NaN
# 4                                   Research Manager             NaN
#
#    header.payLow  header.payMed header.payPeriod  header.salaryHigh
# 0            NaN            NaN              NaN                NaN  \
# 1            NaN            NaN              NaN                NaN
# 2            NaN            NaN              NaN                NaN
# 3            NaN            NaN              NaN                NaN
# ...

# %%
header_sel.isna().sum()
# Out:
# header.employerName      3245
# header.jobTitle             0
# header.payHigh         161628
# header.payLow          161628
# header.payMed          161648
# header.payPeriod       161653
# header.salaryHigh      161628
# header.salaryLow       161628
# header.salarySource    161628
# dtype: int64

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# #### job
#
#
# **columnas importantes:**
# - job.description
# - job.jobSource
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
i = 4
job = cat_dict_dfs[df_names[i]]
print('---------------------------------------------------------------------------------')
print(f"Categoria: {df_names[i]}")
print(job.head())
print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Categoria: df_job
#                                      job.description     job.discoverDate
# 0  We are the drivers of the future who offer a g...  2019-10-24T04:52:23  \
# 1  <strong></strong>\n<br/><br/>\n<strong></stron...  2019-11-04T03:59:14
# 2  Dottori.it &egrave; il motore di ricerca che t...  2019-10-28T12:48:55
# 3  Codup is looking for a Senior SQA Engineer for...  2019-11-04T07:00:20
# 4  <strong>Department:</strong> Research &amp; Op...  2019-11-01T13:40:48
#
#    job.eolHashCode  job.importConfigId  job.jobReqId.long  job.jobReqId.int
# 0         -2041513               75613       4.101124e+09               NaN  \
# 1        320139505               91874       4.202175e+09               NaN
# 2      -1836661938              252306       4.069122e+09               NaN
# 3        776027520              277822       4.202320e+09               NaN
# ...

# %%
job_sel_col = [ 'job.description', 'job.jobSource']
job_sel = job[job_sel_col]
job_sel.head()
# Out:
#                                      job.description             job.jobSource
# 0  We are the drivers of the future who offer a g...            WorkableHR.com
# 1  <strong></strong>\n<br/><br/>\n<strong></stron...                     taleo
# 2  Dottori.it &egrave; il motore di ricerca che t...  Indeed XML Feed Employer
# 3  Codup is looking for a Senior SQA Engineer for...    Indeed XML Feed Dradis
# 4  <strong>Department:</strong> Research &amp; Op...  Indeed XML Feed Employer

# %%
job_sel.isna().sum()
# Out:
# job.description    4
# job.jobSource      0
# dtype: int64

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# #### map
#
#
# **columnas importantes**
# - map.country
# - map.employerName
# - map.location
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
i = 5

the_map = cat_dict_dfs[df_names[i]]

print('---------------------------------------------------------------------------------')
print(f"Categoria: {df_names[i]}")
print(the_map.head())
print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Categoria: df_map
#   map.country       map.employerName  map.lat  map.lng map.location
# 0      Poland            Modus Group  52.2500  21.0000       Warsaw  \
# 1         NaN   Boehringer Ingelheim  41.1500  -8.6167        Porto
# 2       Italy        Immobiliare.it   45.4667   9.2000        Milan
# 3          PK                  Codup  24.8667  67.0500      Karāchi
# 4          IN  Markelytics Solutions  12.9670  77.5873    Bengaluru
#
#   map.address map.postalCode
# 0         NaN            NaN
# 1         NaN            NaN
# 2         NaN            NaN
# 3         NaN            NaN
# 4         NaN            NaN
# ---------------------------------------------------------------------------------

# %%
the_map_sel_col = ["map.country", "map.employerName", "map.location"]
the_map_sel = the_map[the_map_sel_col]
the_map_sel.head()
# Out:
#   map.country       map.employerName map.location
# 0      Poland            Modus Group       Warsaw
# 1         NaN   Boehringer Ingelheim        Porto
# 2       Italy        Immobiliare.it         Milan
# 3          PK                  Codup      Karāchi
# 4          IN  Markelytics Solutions    Bengaluru

# %%
the_map_sel.isna().sum()
# Out:
# map.country         50028
# map.employerName    18141
# map.location            5
# dtype: int64

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# #### overview
#
#
# **Columnas importantes?**
# - overview.allBenefitsLink
# - overview.allSalariesLink
# - overview.foundedYear
# - overview.industry
# - overview.size
#
# > No tanto, puedo no agregarlas
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
i = 6
overview = cat_dict_dfs[df_names[i]]
print('---------------------------------------------------------------------------------')
print(f"Categoria: {df_names[i]}")
print(overview.head())
print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Categoria: df_overview
#                             overview.allBenefitsLink
# 0  /Benefits/Modus-Group-UK-Benefits-EI_IE2183810...  \
# 1  /Benefits/Boehringer-Ingelheim-UK-Benefits-EI_...
# 2  /Benefits/Immobiliare-it-UK-Benefits-EI_IE1043...
# 3  /Benefits/Codup-UK-Benefits-EI_IE2226886.0,5_I...
# 4  /Benefits/Markelytics-Solutions-UK-Benefits-EI...
#
#                               overview.allPhotosLink
# 0     /Photos/Modus-Group-Office-Photos-E2183810.htm  \
# 1  /Photos/Boehringer-Ingelheim-Office-Photos-E10...
# 2  /Photos/Immobiliare-it-Office-Photos-E1043373.htm
# 3           /Photos/Codup-Office-Photos-E2226886.htm
# 4  /Photos/Markelytics-Solutions-Office-Photos-E8...
#
#                              overview.allReviewsLink
# 0          /Reviews/Modus-Group-Reviews-E2183810.htm  \
# 1   /Reviews/Boehringer-Ingelheim-Reviews-E10416.htm
# ...

# %%
overview_sel_col = ["overview.allBenefitsLink",  "overview.allSalariesLink", \
    "overview.foundedYear", "overview.industry", "overview.size" ]

overview_sel = overview[overview_sel_col]
overview_sel.head()
# Out:
#                             overview.allBenefitsLink
# 0  /Benefits/Modus-Group-UK-Benefits-EI_IE2183810...  \
# 1  /Benefits/Boehringer-Ingelheim-UK-Benefits-EI_...
# 2  /Benefits/Immobiliare-it-UK-Benefits-EI_IE1043...
# 3  /Benefits/Codup-UK-Benefits-EI_IE2226886.0,5_I...
# 4  /Benefits/Markelytics-Solutions-UK-Benefits-EI...
#
#                             overview.allSalariesLink  overview.foundedYear
# 0          /Salary/Modus-Group-Salaries-E2183810.htm                  1993  \
# 1   /Salary/Boehringer-Ingelheim-Salaries-E10416.htm                  1885
# 2       /Salary/Immobiliare-it-Salaries-E1043373.htm                     0
# 3                /Salary/Codup-Salaries-E2226886.htm                     0
# 4  /Salary/Markelytics-Solutions-Salaries-E851555...                  2003
#
#                        overview.industry          overview.size
# 0  Investment Banking & Asset Management  501 to 1000 employees
# 1              Biotech & Pharmaceuticals       10000+ employees
# ...

# %%
overview_sel.isna().sum()
# Out:
# overview.allBenefitsLink    18209
# overview.allSalariesLink    18209
# overview.foundedYear            0
# overview.industry           47405
# overview.size               18209
# dtype: int64

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# #### photos
# **Columnas importantes --> No**
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
i = 7
photos = cat_dict_dfs[df_names[i]]
print('---------------------------------------------------------------------------------')
print(f"Categoria: {df_names[i]}")
print(photos.head())
print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Categoria: df_photos
#    photos
# 0  1687.0
# 1  1688.0
# 2     NaN
# 3     NaN
# 4     NaN
# ---------------------------------------------------------------------------------

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# #### rating
#
# **columnas importantes**
# - rating.recommendToFriend
# - rating.starRating
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
i = 8
rating = cat_dict_dfs[df_names[i]]
print('---------------------------------------------------------------------------------')
print(f"Categoria: {df_names[i]}")
print(rating.head())
print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Categoria: df_rating
#           rating.ceo.name rating.ceo.photo rating.ceo.photo2x
# 0     Liudas Liutkevičius              NaN                NaN  \
# 1  Hubertus von Baumbach               NaN                NaN
# 2                     NaN              NaN                NaN
# 3                     NaN              NaN                NaN
# 4                     NaN              NaN                NaN
#
#    rating.ceo.ratingsCount  rating.ceoApproval  rating.recommendToFriend
# 0                      0.0                -0.1                     -0.10  \
# 1                    123.0                 0.8                      0.76
# 2                      0.0                -1.0                      0.47
# 3                      0.0                -1.0                      0.00
# 4                      0.0                -1.0                      0.67
#
#    rating.starRating
# 0               -0.1
# ...

# %%
rating_sel_col = ["rating.recommendToFriend", "rating.starRating"]
rating_sel = rating[rating_sel_col]
rating_sel.head()
# Out:
#    rating.recommendToFriend  rating.starRating
# 0                     -0.10               -0.1
# 1                      0.76                3.8
# 2                      0.47                2.4
# 3                      0.00                1.5
# 4                      0.67                3.5

# %%
rating_sel.isna().sum()
# Out:
# rating.recommendToFriend    18391
# rating.starRating           18391
# dtype: int64

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# #### Reviews (es un numero)
#
# **columnas importante. No (es solo una columna)**
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
i = 9
reviews = cat_dict_dfs[df_names[i]]
print('---------------------------------------------------------------------------------')
print(f"Categoria: {df_names[i]}")
print(reviews.head())
print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Categoria: df_reviews
#    reviews
# 0     2801
# 1     2802
# 2     2803
# 3     2804
# 4     2805
# ---------------------------------------------------------------------------------

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# #### salary
# **Columnas importantes**
#
# - salary.country.cc3LetterISO
# - salary.country.ccISO
# - salary.country.continent.continentCode
# - salary.country.continent.continentName
# - salary.country.currency.currencyCode
# - salary.country.currency.defaultFractionDigits
# - salary.country.currency.displayName
# - salary.currency.displayName
# - salary.currency.name
# - salary.lastSalaryDate
# - salary.salaries
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
i = 10
salary = cat_dict_dfs[df_names[i]]
print('---------------------------------------------------------------------------------')
print(f"Categoria: {df_names[i]}")
print(salary.head())
print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Categoria: df_salary
#   salary.country.cc3LetterISO salary.country.ccISO
# 0                         NaN                  NaN  \
# 1                         GBR                   GB
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 4                         NaN                  NaN
#
#   salary.country.continent.continentCode
# 0                                    NaN  \
# 1                                     EU
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   salary.country.continent.continentName  salary.country.continent.id
# 0                                    NaN                          NaN  \
# 1                                 Europe                          4.0
# 2                                    NaN                          NaN
# ...

# %%
salary.isna().sum()
# Out:
# salary.country.cc3LetterISO                      88513
# salary.country.ccISO                             88513
# salary.country.continent.continentCode           88513
# salary.country.continent.continentName           88513
# salary.country.continent.id                      88513
# salary.country.continent.new                     88513
# salary.country.countryFIPS                       88513
# salary.country.currency.currencyCode             88513
# salary.country.currency.defaultFractionDigits    88513
# salary.country.currency.displayName              88513
# salary.country.currency.id                       88513
# salary.country.currency.name                     88513
# salary.country.currency.negativeTemplate         88513
# salary.country.currency.new                      88513
# salary.country.currency.positiveTemplate         88513
# salary.country.currency.symbol                   88513
# salary.country.currencyCode                      88513
# ...

# %%
salary_sel_col = ["salary.country.cc3LetterISO", "salary.country.ccISO", \
"salary.country.continent.continentCode", "salary.country.continent.continentName", \
"salary.country.currency.currencyCode", "salary.country.currency.defaultFractionDigits",\
"salary.country.currency.displayName", "salary.currency.displayName", "salary.currency.name", \
    "salary.lastSalaryDate","salary.salaries"]
salary_sel = salary[salary_sel_col]
salary_sel.head()
# Out:
#   salary.country.cc3LetterISO salary.country.ccISO
# 0                         NaN                  NaN  \
# 1                         GBR                   GB
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 4                         NaN                  NaN
#
#   salary.country.continent.continentCode
# 0                                    NaN  \
# 1                                     EU
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   salary.country.continent.continentName salary.country.currency.currencyCode
# 0                                    NaN                                  NaN  \
# 1                                 Europe                                  GBP
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# ...

# %%
salary_sel.isna().sum()
# Out:
# salary.country.cc3LetterISO                      88513
# salary.country.ccISO                             88513
# salary.country.continent.continentCode           88513
# salary.country.continent.continentName           88513
# salary.country.currency.currencyCode             88513
# salary.country.currency.defaultFractionDigits    88513
# salary.country.currency.displayName              88513
# salary.currency.displayName                      88513
# salary.currency.name                             88513
# salary.lastSalaryDate                            88513
# salary.salaries                                  18141
# dtype: int64

# %%
salary_sel_col_v2 = ["salary.currency.name", "salary.lastSalaryDate", "salary.salaries"]
salary_sel_v2 = salary[salary_sel_col_v2]

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# #### wwfu
#
# No se que es esta columna
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
i = 11
wwfu = cat_dict_dfs[df_names[i]]
print('---------------------------------------------------------------------------------')
print(f"Categoria: {df_names[i]}")
print(wwfu.tail())
print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Categoria: df_wwfu
#         wwfu
# 165285   NaN
# 165286   NaN
# 165287   NaN
# 165288   NaN
# 165289   NaN
# ---------------------------------------------------------------------------------

# %%
# cat_dict_dfs[df_names[i]].copy().dropna()

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ### Columnas seleccionadas
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
s1 = gaTrackerData_sel_col.copy()
s2 = header_sel_col.copy()
s3 = job_sel_col.copy()
s4 = the_map_sel_col.copy()
s5 =rating_sel_col.copy()
s6 = salary_sel_v2.copy()
sel_col = [*s1, *s2, *s3, *s4, *s5, *s6]

sel_col
# Out:
# ['gaTrackerData.empName',
#  'gaTrackerData.empSize',
#  'gaTrackerData.industry',
#  'gaTrackerData.jobTitle',
#  'gaTrackerData.location',
#  'gaTrackerData.sector',
#  'header.employerName',
#  'header.jobTitle',
#  'header.payHigh',
#  'header.payLow',
#  'header.payMed',
#  'header.payPeriod',
#  'header.salaryHigh',
#  'header.salaryLow',
#  'header.salarySource',
#  'job.description',
#  'job.jobSource',
#  'map.country',
#  'map.employerName',
#  'map.location',
#  'rating.recommendToFriend',
#  'rating.starRating',
#  'salary.currency.name',
#  'salary.lastSalaryDate',
#  'salary.salaries']

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ### Dataframe de glassdoor con menos columnas
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
glassdoor_short_df = df3[sel_col]

glassdoor_short_df.head()
# Out:
#    gaTrackerData.empName gaTrackerData.empSize
# 0            Modus Group              501-1000  \
# 1   Boehringer Ingelheim              10000--1
# 2        Immobiliare.it                201-500
# 3                  Codup                  1-50
# 4  Markelytics Solutions               201-500
#
#                   gaTrackerData.industry
# 0  Investment Banking & Asset Management  \
# 1              Biotech & Pharmaceuticals
# 2                                    NaN
# 3                                    NaN
# 4                             Consulting
#
#                               gaTrackerData.jobTitle gaTrackerData.location
# 0                 Biogas Project Development Manager                 Warsaw  \
# 1  Quality Manager - Boehringer Ingelheim Healthc...                    NaN
# 2     Senior Software Engineer (PHP, Elixir, Python)                 Milano
# 3                                Senior SQA Engineer                Karachi
# ...

# %%
glassdoor_short_df.isna().sum()
# Out:
# gaTrackerData.empName        18209
# gaTrackerData.empSize        18209
# gaTrackerData.industry       47405
# gaTrackerData.jobTitle           0
# gaTrackerData.location       70283
# gaTrackerData.sector         47373
# header.employerName           3245
# header.jobTitle                  0
# header.payHigh              161628
# header.payLow               161628
# header.payMed               161648
# header.payPeriod            161653
# header.salaryHigh           161628
# header.salaryLow            161628
# header.salarySource         161628
# job.description                  4
# job.jobSource                    0
# map.country                  50028
# map.employerName             18141
# map.location                     5
# rating.recommendToFriend     18391
# rating.starRating            18391
# salary.currency.name         88513
# salary.lastSalaryDate        88513
# salary.salaries              18141
# dtype: int64

# %% [markdown]
# ---
# #### Quito las filas que no tengan info de salarios
#
# ---

# %%
mask = glassdoor_short_df['salary.salaries'].isna()
glassdoor_salary_df = glassdoor_short_df.loc[~mask]
print("glassdor_salary_df.shape --> ", glassdoor_salary_df.shape)
# Out:
# glassdor_salary_df.shape -->  (147149, 25)

# %% [markdown]
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# #### Analizamos los datos
#
# ![divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
dfg = glassdoor_salary_df.copy()

dfg['map.country'] = dfg['map.country'].apply(lambda x: x.lower() if isinstance(x, str) else x)
dfg['map.country'].head()
# Out:
# 0    poland
# 1       NaN
# 2     italy
# 3        pk
# 4        in
# Name: map.country, dtype: object

# %%
for n in df1["Name"].unique():
    print(n)
# Out:
# Afghanistan
# Ã…land Islands
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia, Plurinational State of
# Bonaire, Sint Eustatius and Saba
# Bosnia and Herzegovina
# Botswana
# Bouvet Island
# Brazil
# British Indian Ocean Territory
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cambodia
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Costa Rica
# CÃ´te d'Ivoire
# Croatia
# Cuba
# CuraÃ§ao
# Cyprus
# Czech Republic
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# ...

# %%
for c in df1["Code"]:
    print(c)
# Out:
# AF
# AX
# AL
# DZ
# AS
# AD
# AO
# AI
# AQ
# AG
# AR
# AM
# AW
# AU
# AT
# AZ
# BS
# BH
# BD
# BB
# BY
# BE
# BZ
# BJ
# BM
# BT
# BO
# BQ
# BA
# BW
# BV
# BR
# IO
# BN
# BG
# BF
# BI
# KH
# CM
# CA
# CV
# KY
# CF
# TD
# CL
# CN
# CX
# CC
# CO
# KM
# CG
# CD
# CK
# CR
# CI
# HR
# CU
# CW
# CY
# CZ
# DK
# DJ
# DM
# DO
# EC
# EG
# SV
# GQ
# ER
# EE
# ET
# FK
# FO
# FJ
# FI
# FR
# GF
# PF
# TF
# GA
# GM
# GE
# DE
# GH
# GI
# GR
# GL
# GD
# GP
# GU
# GT
# GG
# GN
# GW
# GY
# HT
# HM
# VA
# HN
# HK
# HU
# IS
# IN
# ID
# IR
# IQ
# IE
# IM
# IL
# IT
# JM
# JP
# JE
# JO
# KZ
# KE
# KI
# KP
# KR
# KW
# KG
# LA
# LV
# LB
# LS
# LR
# LY
# LI
# LT
# LU
# MO
# MK
# MG
# MW
# MY
# MV
# ML
# MT
# MH
# MQ
# MR
# MU
# YT
# MX
# FM
# MD
# MC
# MN
# ME
# MS
# MA
# MZ
# MM
# nan
# NR
# NP
# NL
# NC
# NZ
# NI
# NE
# NG
# NU
# NF
# MP
# NO
# OM
# PK
# PW
# PS
# PA
# PG
# PY
# PE
# PH
# PN
# PL
# PT
# PR
# QA
# RE
# RO
# RU
# RW
# BL
# SH
# KN
# LC
# MF
# PM
# VC
# WS
# SM
# ST
# SA
# SN
# RS
# SC
# SL
# ...

# %%
df1["Name"] = df1["Name"].replace("Viet Nam", "Vietnam")
df1["Name"] = df1["Name"].replace("Taiwan, Province of China", "Taiwan")
df1["Name"] = df1["Name"].replace("RÃ©union", "Reunion")
df1["Name"] = df1["Name"].replace("Korea, Democratic People's Republic of", "North Korea")
df1["Name"] = df1["Name"].replace("Korea, Republic of", "South Korea")
df1["Name"] = df1["Name"].replace("Tanzania, United Republic of", "Tanzania")
df1["Name"] = df1["Name"].replace("Dubai (United Arab Emirates)", "United Arab Emirates")
df1["Name"] = df1["Name"].replace("Russian Federation", "Russia")
df1["Name"] = df1["Name"].replace("Macedonia, the Former Yugoslav Republic of", "Macedonia")
df1["Name"] = df1["Name"].replace("CÃ´te d'Ivoire", "côte d'ivoire")
df1["Name"] = df1["Name"].replace("Venezuela, Bolivarian Republic of", "Venezuela")
df1["Name"] = df1["Name"].replace("Moldova, Republic of", "Moldova")


df1["Code"] = df1["Code"].replace('GB', 'UK')
df1["Code"] = df1["Code"].replace('US', 'USA')

# %%
country_name = df1['Name'].apply(lambda x: x.lower() if isinstance(x,str) else x).tolist()
country_code = df1["Code"].apply(lambda x: x.lower() if isinstance(x,str) else x).tolist()


code_to_name_dict = {k:v for k,v in zip(country_code,country_name)}
name_to_code_dict = {k:v for k,v in zip(country_name, country_code)}

# %%
code_to_name_dict
# Out:
# {'af': 'afghanistan',
#  'ax': 'ã…land islands',
#  'al': 'albania',
#  'dz': 'algeria',
#  'as': 'american samoa',
#  'ad': 'andorra',
#  'ao': 'angola',
#  'ai': 'anguilla',
#  'aq': 'antarctica',
#  'ag': 'antigua and barbuda',
#  'ar': 'argentina',
#  'am': 'armenia',
#  'aw': 'aruba',
#  'au': 'australia',
#  'at': 'austria',
#  'az': 'azerbaijan',
#  'bs': 'bahamas',
#  'bh': 'bahrain',
#  'bd': 'bangladesh',
#  'bb': 'barbados',
#  'by': 'belarus',
#  'be': 'belgium',
#  'bz': 'belize',
#  'bj': 'benin',
#  'bm': 'bermuda',
#  'bt': 'bhutan',
#  'bo': 'bolivia, plurinational state of',
#  'bq': 'bonaire, sint eustatius and saba',
#  'ba': 'bosnia and herzegovina',
#  'bw': 'botswana',
#  'bv': 'bouvet island',
#  'br': 'brazil',
#  'io': 'british indian ocean territory',
#  'bn': 'brunei darussalam',
#  'bg': 'bulgaria',
#  'bf': 'burkina faso',
#  'bi': 'burundi',
#  'kh': 'cambodia',
#  'cm': 'cameroon',
#  'ca': 'canada',
#  'cv': 'cape verde',
#  'ky': 'cayman islands',
# ...

# %%
dfg['map.country'] = dfg['map.country'].replace('nederland', 'netherlands')
dfg['map.country'] = dfg['map.country'].replace('england', 'united kingdom')
dfg['map.country'] = dfg['map.country'].replace('india-india', 'india')
dfg['map.country'] = dfg['map.country'].replace('cheshire', 'united kingdom')
dfg['map.country'] = dfg['map.country'].replace('kingdom', 'united kingdom')
dfg['map.country'] = dfg['map.country'].replace('us', 'usa')
dfg['map.country'] = dfg['map.country'].replace('dubai (united arab emirates)', 'united arab emirates')
dfg['map.country'] = dfg['map.country'].replace('taiwan [tw]', 'taiwan')
dfg['map.country'] = dfg['map.country'].replace('santa oliva', 'spain')
dfg['map.country'] = dfg['map.country'].replace('viet nam', 'vietnam')
dfg['map.country'] = dfg['map.country'].replace('macedonia, republic of', 'macedonia')
dfg['map.country'] = dfg['map.country'].replace('munich', 'germany')
dfg['map.country'] = dfg['map.country'].replace('dublin, dublin (ireland)', 'ireland')
dfg['map.country'] = dfg['map.country'].replace('cn - china', 'china')
dfg['map.country'] = dfg['map.country'].replace('hong kong (hong kong)', 'china')
dfg['map.country'] = dfg['map.country'].replace('deutschland', 'germany')
dfg['map.country'] = dfg['map.country'].replace('stockholm', 'sweden')
dfg['map.country'] = dfg['map.country'].replace('japan [jp]', 'japan')
dfg['map.country'] = dfg['map.country'].replace('france-saint-germain', 'france')
dfg['map.country'] = dfg['map.country'].replace('wroclaw,', 'poland')
dfg['map.country'] = dfg['map.country'].replace('méxico', 'mexico')
dfg['map.country'] = dfg['map.country'].replace('makati city, philippines', 'philippines')
dfg['map.country'] = dfg['map.country'].replace('bangalore', 'india')
dfg['map.country'] = dfg['map.country'].replace('schweiz', 'switzerland')
dfg['map.country'] = dfg['map.country'].replace('korea (south)', 'south korea')
dfg['map.country'] = dfg['map.country'].replace('hu - hungary', 'hungary')
dfg['map.country'] = dfg['map.country'].replace('korea', 'south korea')
dfg['map.country'] = dfg['map.country'].replace('brasil', 'brazil')
dfg['map.country'] = dfg['map.country'].replace('telangana', 'india')
dfg['map.country'] = dfg['map.country'].replace('in-in', 'india')
dfg['map.country'] = dfg['map.country'].replace('romania.', 'romania')

dfg['map.country'] = dfg['map.country'].replace('jp - japan.', 'japan')
dfg['map.country'] = dfg['map.country'].replace('cork (ireland)', 'ireland')
dfg['map.country'] = dfg['map.country'].replace('scotland, uk', 'united kingdom')
dfg['map.country'] = dfg['map.country'].replace('congo,', 'congo')
dfg['map.country'] = dfg['map.country'].replace('czech republic-cz', 'czech republic')
dfg['map.country'] = dfg['map.country'].replace('brussels', 'belgium')

dfg['map.country'] = dfg['map.country'].replace('co - colombia', 'colombia')
dfg['map.country'] = dfg['map.country'].replace('malmö', 'sweden')
dfg['map.country'] = dfg['map.country'].replace('san jose, costa rica', 'costa rica')
dfg['map.country'] = dfg['map.country'].replace('munich (germany)', 'germany')
dfg['map.country'] = dfg['map.country'].replace('brazil, colombia', 'colombia')
dfg['map.country'] = dfg['map.country'].replace('fr - france', 'france')
dfg['map.country'] = dfg['map.country'].replace('dalian', 'china')







dfg['map.country.name'] = dfg['map.country'].apply(lambda x: code_to_name_dict[x] if x in country_code else x)
dfg['map.country.code'] = dfg['map.country'].apply(lambda x: name_to_code_dict[x] if x in country_name else x)

# %%
dfg[['map.country','map.country.name', 'map.country.code']].head()
# Out:
#   map.country map.country.name map.country.code
# 0      poland           poland               pl
# 1         NaN          namibia              NaN
# 2       italy            italy               it
# 3          pk         pakistan               pk
# 4          in            india               in

# %%
dfg['map.country.name'].unique()
# Out:
# array(['poland', 'namibia', 'italy', 'pakistan', 'india', 'israel',
#        'france', 'indonesia', 'hong kong', 'united states',
#        'united arab emirates', 'belgium', 'south korea', 'united kingdom',
#        'malaysia', 'nigeria', 'singapore', 'spain', 'canada', 'ukraine',
#        'austria', 'romania', 'germany', 'saudi arabia', 'argentina',
#        'thailand', 'south africa', 'new zealand', 'netherlands',
#        'luxembourg', 'ireland', 'ghana', 'uganda', 'egypt', 'australia',
#        'mexico', 'taiwan', 'sweden', 'philippines', 'slovakia', 'china',
#        'lithuania', 'myanmar', 'gb', 'saint kitts and nevis',
#        'czech republic', 'turkey', 'uzbekistan', 'finland', 'japan',
#        'russia', 'portugal', 'switzerland', 'denmark', 'serbia',
#        'zimbabwe', 'kenya', 'che', 'brazil', 'qatar', 'hungary',
#        'belarus', 'greece', 'estonia', 'vietnam', 'cyprus', 'chile',
#        'tanzania', 'panama', 'uruguay', 'costa rica', 'bulgaria',
# ...

# %%
dfg['map.country.code'].unique()
# Out:
# array(['pl', nan, 'it', 'pk', 'in', 'il', 'fr', 'id', 'hk', 'usa', 'ae',
#        'be', 'kr', 'uk', 'my', 'ng', 'sg', 'es', 'ca', 'ua', 'at', 'ro',
#        'de', 'sa', 'ar', 'th', 'za', 'nz', 'nl', 'lu', 'ie', 'gh', 'ug',
#        'eg', 'au', 'mx', 'tw', 'se', 'ph', 'sk', 'cn', 'lt', 'mm', 'gb',
#        'kn', 'cz', 'tr', 'uz', 'fi', 'jp', 'ru', 'pt', 'ch', 'dk', 'rs',
#        'zw', 'ke', 'che', 'br', 'qa', 'hu', 'by', 'gr', 'ee', 'vn', 'cy',
#        'cl', 'tz', 'pa', 'uy', 'cr', 'bg', 'jo', 'bd', 'is', 'jm', 'al',
#        'pe', 'no', 'mt', 'sgp', 'mz', 'kh', 'lb', '96', 'kw', 'et', 'bh',
#        'isr', 'si', 'co', 'tn', 'hr', 'irl', 'om', 'fra', 'mw', 'lv',
#        'lk', 'idn', 'ind', 'hun', 'dz', 'ata', 'qat', 'afg', 'mk', 'cm',
#        'ht', 'dj', 'mu', 'are', 'bw', 'mg', 'mys', 'bn', 'ir', 'irq',
#        'bb', 'kz', 'esp', 'do', 'ge', 'pg', 'np', 'can', 'chn', 'ci',
#        'aus', 'ly', 'ma', 'dnk', 'sp', 'rw', 'am', 'iq', 'ita', 'ho',
# ...

# %%
dfg.to_csv('../data/clean_glassdoor.csv', index=False)

# %%
# probamos si cargo bien
dfg2 = pd.read_csv('../data/clean_glassdoor.csv')
dfg2.head()
# Out:
#    gaTrackerData.empName gaTrackerData.empSize
# 0            Modus Group              501-1000  \
# 1   Boehringer Ingelheim              10000--1
# 2        Immobiliare.it                201-500
# 3                  Codup                  1-50
# 4  Markelytics Solutions               201-500
#
#                   gaTrackerData.industry
# 0  Investment Banking & Asset Management  \
# 1              Biotech & Pharmaceuticals
# 2                                    NaN
# 3                                    NaN
# 4                             Consulting
#
#                               gaTrackerData.jobTitle gaTrackerData.location
# 0                 Biogas Project Development Manager                 Warsaw  \
# 1  Quality Manager - Boehringer Ingelheim Healthc...                    NaN
# 2     Senior Software Engineer (PHP, Elixir, Python)                 Milano
# 3                                Senior SQA Engineer                Karachi
# ...

# %%
dfg3 = dfg2[['gaTrackerData.jobTitle', 'gaTrackerData.empName', 'gaTrackerData.empSize','map.country.name', 'map.country.code', 'salary.currency.name', 'salary.salaries']]

rename_dict = {'gaTrackerData.jobTitle':'jobTitle', 'gaTrackerData.empName':'companyName',
              'gaTrackerData.empSize':'companySize', 'map.country.name':'countryName', 'map.country.code':'countryCode',
              'salary.currency.name':'currency','salary.salaries':'salary'}
dfg3 = dfg3.rename(rename_dict, axis=1)
dfg3.head()
# Out:
#                                             jobTitle            companyName
# 0                 Biogas Project Development Manager            Modus Group  \
# 1  Quality Manager - Boehringer Ingelheim Healthc...   Boehringer Ingelheim
# 2     Senior Software Engineer (PHP, Elixir, Python)        Immobiliare.it
# 3                                Senior SQA Engineer                  Codup
# 4                                   Research Manager  Markelytics Solutions
#
#   companySize countryName countryCode              currency  salary
# 0    501-1000      poland          pl                   NaN  2483.0
# 1    10000--1     namibia         NaN  United Kingdom Pound  2484.0
# 2     201-500       italy          it                   NaN  2485.0
# 3        1-50    pakistan          pk                   NaN  2486.0
# 4     201-500       india          in                   NaN  2487.0

# %%
dfg3.to_csv('../DATA/clean_glassdoor_rename.csv')
